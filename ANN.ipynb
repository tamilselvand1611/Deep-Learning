# %%
# !pip install tensorflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data=pd.read_csv("smart_meter_data.csv")
data
# Out:
#                 Timestamp  Electricity_Consumed  Temperature  Humidity  \
# 0     2024-01-01 00:00:00              0.457786     0.469524  0.396368
# 1     2024-01-01 00:30:00              0.351956     0.465545  0.451184
# 2     2024-01-01 01:00:00              0.482948     0.285415  0.408289
# 3     2024-01-01 01:30:00              0.628838     0.482095  0.512308
# 4     2024-01-01 02:00:00              0.335974     0.624741  0.672021
# ...                   ...                   ...          ...       ...
# 4995  2024-04-14 01:30:00              0.366839     0.701004  0.362397
# 4996  2024-04-14 02:00:00              0.493568     0.258212  0.677895
# 4997  2024-04-14 02:30:00              0.893818     0.431739  0.688926
# 4998  2024-04-14 03:00:00              0.509673     0.592927  0.366151
# 4999  2024-04-14 03:30:00              0.233656     0.612872  0.473481
#
#       Wind_Speed  Avg_Past_Consumption Anomaly_Label
# 0       0.445441              0.692057        Normal
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Electricity_Consumed', 'Temperature', 'Humidity',
#        'Wind_Speed', 'Avg_Past_Consumption', 'Anomaly_Label'],
#       dtype='object')

# %%
data["Anomaly_Label"].value_counts()
# Out:
# Anomaly_Label
# Normal      4750
# Abnormal     250
# Name: count, dtype: int64

# %%
X=data[["Electricity_Consumed","Temperature","Humidity","Wind_Speed","Avg_Past_Consumption"]]
X.values
# Out:
# array([[0.45778569, 0.46952446, 0.39636836, 0.4454406 , 0.69205721],
#        [0.35195595, 0.46554477, 0.45118441, 0.45872929, 0.53987374],
#        [0.48294809, 0.28541499, 0.40828897, 0.47036041, 0.61472396],
#        ...,
#        [0.89381837, 0.43173895, 0.6889256 , 0.50803789, 0.68109888],
#        [0.5096727 , 0.59292656, 0.3661509 , 0.66821811, 0.710599  ],
#        [0.23365573, 0.61287204, 0.47348062, 0.2683062 , 0.55528629]])

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %%
y=data["Anomaly_Label"]
y.values
# Out:
# array(['Normal', 'Normal', 'Normal', ..., 'Abnormal', 'Normal', 'Normal'],
#       dtype=object)

# %%
le=LabelEncoder()
y=le.fit_transform(y)

# %%
print(le.classes_)
# Out:
# ['Abnormal' 'Normal']

# %%
pred = model.predict(test)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# [[0.41725126]]

# %%
model=Sequential()
model.add(Dense(8, activation="relu"))
model.add(Dense(4, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8028 - loss: 0.6202
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9500 - loss: 0.3551
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9500 - loss: 0.2488
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9500 - loss: 0.2275
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9500 - loss: 0.2168
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9500 - loss: 0.2090
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9500 - loss: 0.2030
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1974
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1918
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1859
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1801
# ...

# %%
electricity = float(input("Enter Electricity Consumed: "))
temperature = float(input("Enter Temperature: "))
humidity = float(input("Enter Humidity: "))
wind_speed = float(input("Enter Wind Speed: "))
avg = float(input("Enter Average Past Consumption: "))
# Out:
# Enter Electricity Consumed:  0.457786
# Enter Temperature:  0.469524
# Enter Humidity:  0.445441
# Enter Wind Speed:  0.445441
# Enter Average Past Consumption:  0.692057

# %%
test = np.array([[electricity, temperature, humidity, wind_speed, avg]])
test=scaler.transform(test)
pred = model.predict(test)
if pred[0][0] > 0.5:
    print("Prediction:", le.inverse_transform([1])[0])
else:
    print("Prediction:", le.inverse_transform([0])[0])
# Out:
# C:\Users\tamil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Prediction: Normal
